# %% [markdown]
# Current competition metric implies segmenation task. However one valid approach could incorporate object detection. In this direcrion and borrowing stuff from Kevin's excellent kernel [https://www.kaggle.com/kmader/baseline-u-net-model-part-1](http://), we attempt to extract bounding boxes information from binary rle-encoded masks.

# %%
import os
import cv2
from tqdm import tqdm
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from skimage.io import imread
import matplotlib.pyplot as plt
from skimage.segmentation import mark_boundaries
from skimage.measure import label, regionprops
from skimage.util.montage import montage2d as montage
montage_rgb = lambda x: np.stack([montage(x[:, :, :, i]) for i in range(x.shape[3])], -1)
ship_dir = '../input'
test_image_dir = os.path.join(ship_dir, 'test')

from skimage.morphology import label
def multi_rle_encode(img):
    labels = label(img[:, :, 0])
    return [rle_encode(labels==k) for k in np.unique(labels[labels>0])]

# ref: https://www.kaggle.com/paulorzp/run-length-encode-and-decode
def rle_encode(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle_decode(mask_rle, shape=(768, 768)):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction

def masks_as_image(in_mask_list, all_masks=None):
    # Take the individual ship masks and create a single mask array for all ships
    if all_masks is None:
        all_masks = np.zeros((768, 768), dtype = np.int16)
    #if isinstance(in_mask_list, list):
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks += rle_decode(mask)
    return np.expand_dims(all_masks, -1)

# %% [markdown]
# Let us read the masks:

# %%
masks = pd.read_csv(os.path.join('../input/',
                                 'test_ship_segmentations.csv'))
print(masks.shape[0], 'masks found')
print(masks['ImageId'].value_counts().shape[0])
masks.head()
# Out:
# 100693 masks found
# 88486
#          ImageId                                      EncodedPixels
# 0  0001124c7.jpg                                                NaN
# 1  000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...
# 2  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 3  000194a2d.jpg  254389 9 255157 17 255925 17 256693 17 257461 ...
# 4  000194a2d.jpg  198320 10 199088 10 199856 10 200624 10 201392...

# %% [markdown]
# and keep only those that contain ships. Keep in mind that image files can be repeated many times in the csv file. So a unique operator will give us the unique filenames that contain ships.

# %%
images_with_ship = masks.ImageId[masks.EncodedPixels.isnull()==False]
images_with_ship = np.unique(images_with_ship.values)
print('There are ' +str(len(images_with_ship)) + ' image files with masks')
images_with_ship.shape[0]
# Out:
# There are 13486 image files with masks
# 13486

# %%
def cut_image(im, desired_size, x, y, w, h):
    # cut subimage has top-left = (x,y) and (width,height) = (w,h) with desired size presets
    # print(str(x) + ' ' + str(y) + ' ' + str(w) + ' ' + str(h))

    centerX = x + w/2
    centerY = y + h/2

    if w <= desired_size and h <= desired_size:
        newSize = desired_size
    else:
        if w < h:
            newSize = h
        else:
            newSize = w

    newWidth = newSize
    newHeight = newSize
    newX = centerX - newSize/2
    newY = centerY - newSize/2

    if newX < 0:
        newX = 0
    if newY < 0:
        newY = 0
    if newX + newWidth >= im.shape[1]:
        newX = im.shape[1] - newWidth
    if newY + newHeight >= im.shape[0]:
        newY = im.shape[0] - newHeight

    subimg = im[int(newY): int(newY + newHeight),int(newX):int(newX + newWidth)]

    # print(str(newX) + ' ' + str(newY) + ' ' + str(newWidth) + ' ' + str(newHeight))

    if newSize > desired_size:
        subimg = cv2.resize(subimg, (desired_size, desired_size), interpolation=cv2.INTER_CUBIC)

    return subimg, newX, newY, newWidth, newHeight

# %% [markdown]
# In order to extract the bounding box we:
# 1. Load mask as binary numpy array using Kevin's `masks_as_image`)
#
# 2. Label  connected regions of this mask using `skimage.measure.label`
#
# 3. Measure morphological properties of these connected regions and keep the bounding box (`skimage.measure.regionprops`). For each connected region a bounding box of the form  (min_row, min_col, max_row, max_col) is returned.
#
# (*Note: Ships masks touching each other would be considered as one. See Image 00021ddc3.jpg below. This may hurt detection performance but we can find ways to further split them !* )
#
# Let us view some  examples:

# %%
for i in range(images_with_ship.shape[0]):
    image = images_with_ship[i]

#     fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15, 5))
    img_0 = cv2.imread(test_image_dir+'/' + image)
    rle_0 = masks.query('ImageId=="'+image+'"')['EncodedPixels']
    mask_0 = masks_as_image(rle_0)
    #
    # 
    lbl_0 = label(mask_0) 
    props = regionprops(lbl_0)
    img_1 = img_0.copy()
    print ('Image', image)
    j = 0
    for prop in props:
        print('Found bbox', prop.bbox)
        cv2.rectangle(img_1, (prop.bbox[1], prop.bbox[0]), (prop.bbox[3], prop.bbox[2]), (255, 0, 0), 2)
#         roi = img_0[prop.bbox[0]:prop.bbox[2], prop.bbox[1]:prop.bbox[3]]
#         roi = cv2.resize(roi, (32, 32)) 
        roi, newX, newY, newWidth, newHeight = cut_image(img_0, 80, prop.bbox[1], prop.bbox[0], prop.bbox[3]-prop.bbox[1], prop.bbox[2]-prop.bbox[0])
        cv2.imwrite(os.path.join('./', 'ship80/')+image[:9]+'_'+str(j)+'.jpg', roi)
        j = j + 1

#     ax1.imshow(img_0)
#     ax1.set_title('Image')
#     ax2.set_title('Mask')
#     ax3.set_title('Image with derived bounding box')
#     ax2.imshow(mask_0[...,0], cmap='gray')
#     ax3.imshow(img_1)
#     plt.show()
# Out:
# Image 000194a2d.jpg
# Found bbox (377, 67, 387, 85)
# Found bbox (174, 258, 185, 306)
# Found bbox (178, 331, 197, 370)
# Found bbox (287, 469, 307, 492)
# Image 000532683.jpg
# Found bbox (460, 597, 474, 604)
# Found bbox (756, 738, 763, 747)
# Image 0005d6d95.jpg
# Found bbox (171, 345, 190, 367)
# Image 001234638.jpg
# Found bbox (401, 170, 530, 327)
# Image 0017c19d6.jpg
# Found bbox (514, 428, 527, 442)
# Found bbox (449, 528, 469, 548)
# Image 0018e5d6c.jpg
# Found bbox (127, 72, 205, 355)
# Image 001bcf222.jpg
# Found bbox (345, 285, 361, 307)
# Image 001ed8b9b.jpg
# Found bbox (183, 8, 276, 338)
# Image 0022f64e5.jpg
# Found bbox (627, 135, 662, 204)
# Image 0027854cc.jpg
# Found bbox (316, 0, 381, 84)
# Image 002868a5c.jpg
# Found bbox (622, 226, 630, 232)
# Image 00286e8b9.jpg
# Found bbox (471, 445, 590, 569)
# Image 002943412.jpg
# Found bbox (594, 186, 719, 330)
# Found bbox (140, 268, 193, 342)
# Found bbox (215, 391, 236, 416)
# Image 003520305.jpg
# Found bbox (553, 1, 576, 68)
# Found bbox (711, 57, 736, 109)
# Found bbox (147, 110, 176, 194)
# Found bbox (571, 316, 591, 363)
# Found bbox (548, 502, 569, 564)
# Found bbox (481, 673, 512, 725)
# Image 00371aa92.jpg
# Found bbox (583, 270, 599, 295)
# Image 0038cbe45.jpg
# Found bbox (621, 283, 639, 313)
# Image 003b48a9e.jpg
# Found bbox (716, 379, 726, 387)
# Found bbox (451, 459, 464, 466)
# Image 00497c23d.jpg
# Found bbox (434, 343, 452, 358)
# Image 004e94ecb.jpg
# Found bbox (486, 43, 508, 122)
# Image 00578738f.jpg
# Found bbox (601, 32, 613, 51)
# Image 005c8e121.jpg
# Found bbox (127, 384, 236, 471)
# Image 0062e4cf1.jpg
# Found bbox (88, 140, 98, 154)
# Image 00640a1af.jpg
# Found bbox (125, 70, 248, 149)
# Found bbox (654, 439, 677, 506)
# Found bbox (264, 711, 285, 732)
# Image 0067a8e04.jpg
# Found bbox (751, 24, 768, 44)
# Found bbox (177, 53, 192, 69)
# Found bbox (686, 191, 706, 217)
# Image 0068b3804.jpg
# Found bbox (246, 244, 269, 310)
# Found bbox (326, 306, 354, 396)
# Image 006da0c7b.jpg
# Found bbox (644, 452, 661, 467)
# Image 006f392d7.jpg
# Found bbox (626, 70, 649, 93)
# Found bbox (518, 399, 531, 413)
# Image 007b25c03.jpg
# Found bbox (434, 96, 513, 253)
# Found bbox (186, 114, 192, 129)
# Found bbox (303, 630, 354, 693)
# Found bbox (619, 719, 768, 766)
# Image 009751652.jpg
# Found bbox (513, 453, 560, 545)
# Image 00a6fef47.jpg
# Found bbox (574, 510, 595, 519)
# Image 00a9adaa4.jpg
# Found bbox (304, 61, 315, 76)
# Found bbox (268, 141, 284, 158)
# Found bbox (219, 280, 244, 303)
# Found bbox (160, 324, 183, 339)
# Found bbox (20, 422, 39, 437)
# Image 00a9be085.jpg
# Found bbox (287, 36, 369, 102)
# Found bbox (662, 603, 680, 620)
# Found bbox (672, 618, 711, 660)
# Image 00b101ed7.jpg
# Found bbox (492, 47, 537, 111)
# Image 00b71d048.jpg
# Found bbox (103, 26, 150, 55)
# Image 00c3aee3d.jpg
# Found bbox (99, 147, 112, 152)
# Found bbox (52, 191, 93, 263)
# Found bbox (291, 498, 322, 519)
# Image 00c3bafa8.jpg
# Found bbox (258, 678, 276, 701)
# Image 00c3e1386.jpg
# Found bbox (383, 254, 461, 287)
# Image 00c498ef4.jpg
# Found bbox (422, 472, 484, 538)
# Image 00c54cf6e.jpg
# Found bbox (109, 558, 193, 596)
# Image 00c885f4f.jpg
# Found bbox (325, 364, 358, 394)
# Image 00c996565.jpg
# Found bbox (219, 138, 231, 149)
# Found bbox (612, 194, 622, 204)
# Found bbox (58, 401, 77, 420)
# Image 00ce2c1c0.jpg
# Found bbox (501, 281, 640, 543)
# Image 00dffdc42.jpg
# Found bbox (257, 709, 274, 724)
# Image 00e56cc3c.jpg
# Found bbox (538, 734, 562, 757)
# Image 00e603959.jpg
# Found bbox (342, 599, 361, 644)
# Image 00ee04562.jpg
# Found bbox (9, 112, 31, 196)
# Found bbox (158, 282, 184, 361)
# Found bbox (442, 319, 481, 402)
# Image 00f4494b4.jpg
# Found bbox (538, 400, 557, 411)
# Found bbox (618, 463, 630, 474)
# Found bbox (757, 524, 768, 537)
# Image 00f89a059.jpg
# Found bbox (519, 61, 530, 74)
# Image 01031cea7.jpg
# Found bbox (579, 0, 655, 52)
# Image 010396a0e.jpg
# Found bbox (254, 307, 279, 364)
# Found bbox (560, 576, 611, 732)
# Image 0104ed53e.jpg
# Found bbox (354, 160, 377, 214)
# Found bbox (132, 519, 178, 617)
# Image 010b1e6aa.jpg
# Found bbox (608, 304, 629, 369)
# Found bbox (607, 615, 622, 647)
# Image 010cbbfa0.jpg
# Found bbox (663, 200, 673, 221)
# Found bbox (618, 529, 624, 538)
# Found bbox (474, 698, 494, 703)
# Image 010e15afe.jpg
# Found bbox (407, 0, 442, 63)
# Found bbox (301, 11, 322, 51)
# Found bbox (348, 83, 369, 117)
# Found bbox (397, 84, 440, 142)
# Found bbox (334, 117, 356, 144)
# Image 01109440b.jpg
# Found bbox (453, 428, 463, 438)
# Found bbox (433, 554, 441, 563)
# Image 0114cb925.jpg
# Found bbox (408, 495, 486, 535)
# Found bbox (326, 531, 337, 537)
# Image 01178499a.jpg
# Found bbox (319, 299, 440, 438)
# Image 01193c983.jpg
# Found bbox (71, 0, 91, 12)
# Image 0123af2ee.jpg
# Found bbox (244, 644, 261, 666)
# Image 012735107.jpg
# Found bbox (427, 89, 446, 111)
# Found bbox (331, 678, 341, 689)
# Image 013048d62.jpg
# Found bbox (480, 272, 595, 399)
# Found bbox (418, 384, 434, 416)
# Found bbox (223, 419, 460, 686)
# Image 0137ee2df.jpg
# Found bbox (129, 28, 180, 83)
# Image 0140787ec.jpg
# Found bbox (627, 415, 684, 532)
# Found bbox (528, 480, 571, 543)
# Found bbox (637, 546, 700, 646)
# Image 014624873.jpg
# Found bbox (126, 359, 340, 546)
# Found bbox (154, 476, 163, 490)
# Image 0148e8c38.jpg
# Found bbox (709, 32, 714, 38)
# Image 014c906b1.jpg
# Found bbox (348, 206, 367, 262)
# Found bbox (95, 369, 121, 458)
# Found bbox (650, 411, 684, 475)
# Found bbox (388, 538, 408, 616)
# Image 01530ba04.jpg
# Found bbox (553, 179, 678, 274)
# Image 015861bab.jpg
# Found bbox (34, 97, 47, 112)
# Image 015e0504c.jpg
# Found bbox (395, 704, 409, 718)
# Image 015e56b00.jpg
# Found bbox (46, 216, 91, 291)
# Found bbox (23, 354, 30, 369)
# Image 0160a797d.jpg
# Found bbox (695, 370, 714, 383)
# Image 0166012e5.jpg
# Found bbox (156, 169, 169, 182)
# Image 0166f83f1.jpg
# Found bbox (377, 5, 389, 27)
# Image 016ca71c9.jpg
# Found bbox (48, 682, 97, 742)
# Image 016dcd260.jpg
# Found bbox (474, 356, 540, 452)
# Found bbox (366, 508, 380, 530)
# Found bbox (160, 658, 187, 768)
# Image 0171499be.jpg
# Found bbox (114, 0, 240, 124)
# Found bbox (337, 95, 379, 125)
# Found bbox (271, 187, 309, 234)
# Image 0178c2489.jpg
# Found bbox (29, 19, 46, 41)
# Found bbox (171, 191, 182, 203)
# Found bbox (208, 198, 217, 208)
# Found bbox (352, 254, 360, 260)
# Image 017b8be5a.jpg
# Found bbox (303, 637, 329, 656)
# Image 01834cb80.jpg
# Found bbox (184, 342, 269, 481)
# Image 0187b087a.jpg
# Found bbox (18, 632, 32, 646)
# Image 018b5ba5b.jpg
# Found bbox (237, 270, 250, 283)
# Image 018b8ef33.jpg
# Found bbox (137, 183, 169, 199)
# Image 01914baf2.jpg
# Found bbox (392, 3, 414, 88)
# Found bbox (513, 113, 528, 157)
# Found bbox (657, 131, 681, 204)
# Found bbox (159, 146, 184, 224)
# Found bbox (312, 169, 330, 206)
# Found bbox (238, 272, 248, 289)
# Found bbox (755, 285, 768, 318)
# Found bbox (447, 286, 462, 329)
# Found bbox (270, 334, 292, 410)
# Found bbox (567, 354, 584, 408)
# Found bbox (440, 388, 466, 468)
# Found bbox (661, 518, 688, 592)
# Found bbox (304, 562, 322, 622)
# Found bbox (516, 657, 534, 734)
# Found bbox (746, 664, 768, 726)
# Image 01924b710.jpg
# Found bbox (664, 426, 678, 435)
# Found bbox (717, 544, 731, 557)
# Image 0193c0713.jpg
# Found bbox (486, 77, 515, 113)
# Image 0198728be.jpg
# Found bbox (230, 176, 317, 320)
# Found bbox (203, 180, 235, 252)
# Found bbox (650, 303, 674, 401)
# Found bbox (476, 553, 521, 637)
# Image 01a5e1c3f.jpg
# Found bbox (358, 32, 364, 37)
# Found bbox (580, 115, 589, 123)
# Image 01b267948.jpg
# Found bbox (62, 254, 123, 348)
# Image 01b2b29c7.jpg
# Found bbox (434, 20, 454, 32)
# Image 01b7347a6.jpg
# Found bbox (657, 428, 664, 438)
# Image 01b87d3d6.jpg
# Found bbox (115, 178, 132, 194)
# Image 01bc908db.jpg
# Found bbox (489, 723, 499, 762)
# Image 01bd540db.jpg
# Found bbox (148, 84, 160, 108)
# Image 01c5e7262.jpg
# Found bbox (680, 302, 688, 309)
# Found bbox (669, 499, 686, 516)
# Found bbox (53, 689, 63, 702)
# Image 01c6da630.jpg
# Found bbox (714, 582, 721, 588)
# Image 01c8395ef.jpg
# Found bbox (362, 193, 387, 209)
# Image 01ca03158.jpg
# Found bbox (654, 451, 659, 454)
# Image 01cecb9b6.jpg
# Found bbox (533, 276, 553, 288)
# Image 01d175183.jpg
# Found bbox (294, 483, 370, 556)
# Found bbox (361, 509, 376, 525)
# Image 01d6c0ada.jpg
# Found bbox (298, 13, 342, 174)
# Image 01d7041bb.jpg
# Found bbox (13, 227, 39, 253)
# Found bbox (65, 277, 141, 351)
# Image 01de1273b.jpg
# Found bbox (718, 6, 768, 167)
# Found bbox (436, 387, 511, 495)
# Image 01e8037b5.jpg
# Found bbox (360, 354, 373, 366)
# Image 01edf4e56.jpg
# Found bbox (440, 250, 478, 262)
# Found bbox (603, 392, 629, 403)
# Image 01ef10853.jpg
# Found bbox (657, 172, 664, 182)
# Found bbox (712, 551, 720, 557)
# Found bbox (714, 558, 723, 567)
# Found bbox (714, 567, 724, 575)
# Found bbox (714, 574, 725, 584)
# Found bbox (715, 582, 725, 595)
# Found bbox (720, 592, 729, 600)
# Image 01f286825.jpg
# Found bbox (16, 215, 24, 221)
# Image 0200612e9.jpg
# Found bbox (565, 292, 663, 568)
# Image 02021c2f9.jpg
# Found bbox (593, 382, 602, 392)
# Found bbox (387, 504, 395, 512)
# Found bbox (343, 586, 351, 594)
# Found bbox (326, 654, 334, 661)
# Image 020364a0c.jpg
# Found bbox (194, 348, 213, 359)
# Found bbox (375, 632, 384, 637)
# Image 020a2bace.jpg
# Found bbox (692, 455, 703, 466)
# Image 020f1afe8.jpg
# Found bbox (302, 174, 482, 461)
# Image 0213b298f.jpg
# Found bbox (752, 491, 765, 506)
# Image 021726b60.jpg
# Found bbox (600, 554, 613, 564)
# Image 022c0e756.jpg
# Found bbox (47, 665, 60, 678)
# Image 023240c31.jpg
# Found bbox (607, 146, 707, 274)
# Image 0235db857.jpg
# Found bbox (249, 165, 278, 330)
# Found bbox (372, 175, 400, 340)
# Found bbox (51, 191, 85, 415)
# Found bbox (7, 225, 33, 399)
# Found bbox (240, 404, 263, 573)
# Found bbox (746, 406, 768, 591)
# Found bbox (0, 447, 22, 616)
# Image 023881a49.jpg
# Found bbox (564, 225, 604, 381)
# Image 023a8c6b4.jpg
# Found bbox (435, 381, 464, 493)
# Image 023aec5ee.jpg
# Found bbox (89, 457, 99, 466)
# Image 0240fc4b8.jpg
# Found bbox (69, 499, 192, 685)
# Image 02421d07b.jpg
# Found bbox (90, 61, 99, 71)
# Image 024248678.jpg
# Found bbox (211, 134, 220, 150)
# Found bbox (262, 142, 268, 156)
# Found bbox (349, 210, 356, 219)
# Found bbox (167, 498, 174, 512)
# Image 025085ccc.jpg
# Found bbox (625, 218, 649, 242)
# Image 025b52a2b.jpg
# Found bbox (97, 434, 107, 448)
# Found bbox (234, 576, 244, 586)
# Image 025baec78.jpg
# Found bbox (196, 33, 218, 94)
# Found bbox (377, 84, 424, 159)
# Found bbox (702, 96, 752, 173)
# Found bbox (498, 243, 525, 290)
# Found bbox (303, 304, 343, 376)
# Found bbox (626, 334, 671, 402)
# Found bbox (472, 481, 508, 534)
# Found bbox (300, 548, 324, 586)
# Found bbox (147, 553, 177, 603)
# Found bbox (650, 579, 703, 655)
# Found bbox (1, 627, 30, 679)
# Found bbox (180, 709, 212, 768)
# Image 0262aaa0d.jpg
# Found bbox (46, 525, 138, 768)
# Image 026bb1723.jpg
# Found bbox (358, 495, 444, 575)
# Image 026dae336.jpg
# Found bbox (7, 286, 32, 366)
# Found bbox (9, 316, 12, 327)
# Image 0272a80e1.jpg
# Found bbox (370, 557, 384, 578)
# Image 027b2269a.jpg
# Found bbox (571, 194, 663, 348)
# Image 027b381f0.jpg
# Found bbox (142, 447, 233, 663)
# Image 02884baad.jpg
# Found bbox (230, 315, 245, 332)
# Found bbox (178, 634, 190, 644)
# Image 0292e9584.jpg
# Found bbox (495, 456, 663, 563)
# Image 0296e8724.jpg
# Found bbox (645, 461, 659, 475)
# Found bbox (608, 542, 619, 553)
# Found bbox (448, 704, 453, 713)
# Image 029883ddf.jpg
# Found bbox (201, 550, 234, 563)
# Image 0299e7726.jpg
# Found bbox (398, 19, 408, 33)
# Found bbox (394, 100, 418, 170)
# Image 02a09371f.jpg
# Found bbox (337, 74, 356, 93)
# Found bbox (276, 88, 292, 106)
# Found bbox (291, 89, 312, 109)
# Found bbox (315, 94, 332, 109)
# Found bbox (282, 104, 293, 116)
# Found bbox (290, 109, 300, 120)
# Found bbox (295, 113, 304, 124)
# Found bbox (228, 179, 247, 197)
# Found bbox (245, 190, 272, 211)
# Image 02a823e11.jpg
# Found bbox (126, 103, 340, 290)
# Found bbox (154, 220, 163, 234)
# Image 02a9756b9.jpg
# Found bbox (592, 23, 606, 49)
# Found bbox (654, 247, 661, 258)
# Image 02b30cdbb.jpg
# Found bbox (678, 5, 717, 56)
# Image 02c086331.jpg
# Found bbox (394, 196, 418, 297)
# Found bbox (604, 624, 623, 667)
# Image 02c314fd7.jpg
# Found bbox (134, 167, 153, 185)
# Image 02cfb3c9d.jpg
# Found bbox (322, 187, 354, 290)
# Image 02d15f352.jpg
# Found bbox (318, 169, 339, 191)
# Image 02d49dfcc.jpg
# Found bbox (269, 154, 326, 229)
# Found bbox (364, 512, 402, 565)
# Found bbox (282, 692, 287, 698)
# Found bbox (583, 732, 595, 742)
# Found bbox (409, 750, 415, 754)
# Found bbox (454, 759, 460, 763)
# Image 02d772058.jpg
# Found bbox (405, 355, 420, 377)
# Image 02d7e346f.jpg
# Found bbox (683, 2, 692, 16)
# Found bbox (538, 498, 545, 511)
# Found bbox (163, 524, 170, 537)
# Image 02d958534.jpg
# Found bbox (429, 584, 442, 600)
# Image 02de1b37d.jpg
# Found bbox (714, 173, 736, 221)
# Found bbox (455, 408, 469, 422)
# Image 02e39612d.jpg
# Found bbox (541, 89, 691, 345)
# Image 02e6a2a59.jpg
# Found bbox (554, 411, 609, 513)
# Found bbox (511, 684, 604, 702)
# Image 02eeba747.jpg
# Found bbox (300, 112, 359, 173)
# Found bbox (105, 219, 145, 243)
# Found bbox (12, 257, 57, 272)
# Found bbox (0, 429, 42, 447)
# Image 02fa41846.jpg
# Found bbox (570, 44, 621, 120)
# Found bbox (125, 691, 186, 750)
# Image 03007ae96.jpg
# Found bbox (724, 247, 768, 304)
# Image 03078635d.jpg
# Found bbox (387, 374, 525, 562)
# Image 030e51946.jpg
# Found bbox (325, 583, 362, 710)
# Image 031101e01.jpg
# Found bbox (542, 673, 639, 768)
# Image 031414527.jpg
# Found bbox (0, 683, 10, 696)
# Image 0318bab62.jpg
# Found bbox (455, 479, 502, 577)
# Image 031db2a4b.jpg
# Found bbox (663, 405, 682, 420)
# Image 03283f72a.jpg
# Found bbox (272, 79, 289, 94)
# Image 0346f7fca.jpg
# Found bbox (24, 297, 41, 315)
# Found bbox (25, 482, 38, 498)
# Image 034a0dddf.jpg
# Found bbox (134, 423, 153, 441)
# Image 034abac62.jpg
# Found bbox (191, 0, 297, 259)
# Image 034e216f0.jpg
# Found bbox (127, 740, 142, 768)
# Image 03504a689.jpg
# Found bbox (117, 465, 133, 503)
# Found bbox (390, 508, 464, 703)
# Image 0350f9c3d.jpg
# Found bbox (9, 253, 68, 294)
# Found bbox (497, 681, 570, 749)
# Image 03527aee7.jpg
# Found bbox (683, 400, 694, 418)
# Image 035edd5ba.jpg
# Found bbox (155, 262, 400, 504)
# Image 037192ffd.jpg
# Found bbox (69, 654, 97, 676)
# Image 0372121e8.jpg
# Found bbox (564, 126, 598, 206)
# Found bbox (91, 236, 99, 253)
# Found bbox (492, 426, 534, 510)
# Found bbox (182, 568, 196, 585)
# Found bbox (697, 604, 740, 682)
# Found bbox (267, 678, 356, 767)
# Image 0372480b7.jpg
# Found bbox (468, 0, 558, 284)
# Image 037642165.jpg
# Found bbox (712, 528, 759, 722)
# Image 0376c100c.jpg
# Found bbox (741, 524, 760, 615)
# Image 037cc9d3e.jpg
# Found bbox (702, 610, 713, 619)
# Found bbox (678, 627, 689, 637)
# Found bbox (728, 638, 739, 648)
# Found bbox (675, 664, 690, 679)
# Found bbox (713, 671, 721, 680)
# Image 0380ebf24.jpg
# Found bbox (68, 400, 76, 408)
# Image 0384a0b91.jpg
# Found bbox (651, 448, 665, 462)
# Image 039ec5586.jpg
# Found bbox (96, 181, 106, 194)
# Image 03a5fd8d2.jpg
# Found bbox (591, 286, 684, 461)
# Image 03a8cb652.jpg
# Found bbox (43, 225, 115, 300)
# Found bbox (77, 562, 149, 636)
# Found bbox (562, 600, 595, 641)
# Image 03b27f7c3.jpg
# Found bbox (350, 642, 551, 753)
# Image 03b77e1f8.jpg
# Found bbox (307, 519, 349, 599)
# Image 03c101b1a.jpg
# Found bbox (560, 297, 719, 442)
# Image 03c2a7431.jpg
# Found bbox (515, 671, 542, 696)
# Image 03c2c78e5.jpg
# Found bbox (368, 445, 401, 536)
# Found bbox (43, 507, 107, 610)
# Image 03c807bd1.jpg
# Found bbox (724, 30, 768, 101)
# Found bbox (727, 451, 761, 486)
# Image 03d075610.jpg
# Found bbox (590, 634, 683, 768)
# Image 03d67b97f.jpg
# Found bbox (138, 446, 159, 472)
# Found bbox (183, 515, 247, 594)
# Image 03d9e6d66.jpg
# Found bbox (322, 25, 332, 34)
# Image 03e12b25c.jpg
# Found bbox (209, 365, 275, 557)
# Found bbox (598, 479, 673, 638)
# Image 03eaa8a5e.jpg
# Found bbox (185, 0, 340, 189)
# Image 03eadd139.jpg
# Found bbox (693, 105, 702, 120)
# Found bbox (505, 510, 514, 526)
# Found bbox (166, 517, 205, 568)
# Found bbox (566, 523, 579, 542)
# Found bbox (724, 561, 737, 577)
# Found bbox (482, 601, 491, 619)
# Found bbox (739, 625, 752, 636)
# Found bbox (733, 634, 745, 645)
# Found bbox (753, 667, 765, 677)
# Found bbox (698, 713, 708, 725)
# Found bbox (692, 719, 702, 731)
# Found bbox (683, 724, 697, 740)
# Image 03f570eac.jpg
# Found bbox (161, 664, 220, 768)
# Image 03fa4f028.jpg
# Found bbox (528, 387, 538, 394)
# Image 040979702.jpg
# Found bbox (700, 99, 742, 119)
# Found bbox (486, 112, 497, 121)
# Found bbox (437, 573, 449, 590)
# Image 040d3a7b0.jpg
# Found bbox (471, 192, 486, 236)
# Found bbox (694, 237, 708, 282)
# Image 0410a455d.jpg
# Found bbox (588, 310, 755, 390)
# Image 04132b93b.jpg
# Found bbox (353, 358, 365, 366)
# Image 0413cfbde.jpg
# Found bbox (400, 150, 584, 244)
# Image 04163641b.jpg
# Found bbox (637, 344, 759, 470)
# Found bbox (439, 363, 510, 430)
# Found bbox (292, 493, 370, 566)
# Image 042ddaae0.jpg
# Found bbox (541, 528, 568, 576)
# Found bbox (147, 549, 177, 613)
# Image 043220e79.jpg
# Found bbox (315, 42, 530, 327)
# Image 0438f4082.jpg
# Found bbox (250, 51, 299, 209)
# Image 043e25f0d.jpg
# Found bbox (96, 487, 120, 512)
# Image 044342421.jpg
# Found bbox (48, 496, 218, 641)
# Image 0444b65af.jpg
# Found bbox (0, 295, 60, 388)
# Image 0448ad6ff.jpg
# Found bbox (445, 475, 496, 589)
# Image 045029812.jpg
# Found bbox (613, 115, 703, 162)
# Image 046861c6f.jpg
# Found bbox (0, 493, 4, 497)
# Found bbox (316, 607, 328, 614)
# Image 046e06d1a.jpg
# Found bbox (499, 85, 536, 143)
# Found bbox (699, 118, 742, 141)
# Found bbox (611, 331, 659, 378)
# Image 046e69c24.jpg
# Found bbox (240, 659, 259, 677)
# Found bbox (186, 703, 198, 717)
# Image 047794cdf.jpg
# Found bbox (698, 257, 764, 321)
# Found bbox (352, 266, 438, 328)
# Found bbox (594, 382, 653, 442)
# Found bbox (706, 534, 758, 592)
# Found bbox (134, 609, 195, 637)
# Found bbox (407, 635, 453, 694)
# Found bbox (102, 735, 152, 768)
# Image 0478ba85c.jpg
# Found bbox (170, 395, 182, 406)
# Image 04875e0d3.jpg
# Found bbox (24, 383, 95, 427)
# Image 0489e53a3.jpg
# Found bbox (200, 547, 244, 648)
# Image 048d10581.jpg
# Found bbox (74, 0, 230, 148)
# Found bbox (262, 351, 492, 607)
# Image 0490b090a.jpg
# Found bbox (537, 87, 571, 115)
# Found bbox (672, 399, 721, 423)
# Found bbox (267, 479, 307, 514)
# Image 049a04990.jpg
# Found bbox (259, 463, 298, 500)
# Image 04a2c262a.jpg
# Found bbox (516, 218, 594, 290)
# Found bbox (708, 256, 742, 280)
# Found bbox (640, 261, 683, 287)
# Found bbox (307, 444, 352, 488)
# Found bbox (299, 459, 311, 473)
# Found bbox (293, 474, 301, 485)
# Found bbox (204, 638, 244, 684)
# Image 04a3438da.jpg
# Found bbox (45, 510, 53, 527)
# Found bbox (90, 513, 101, 527)
# Image 04a48c914.jpg
# Found bbox (349, 719, 371, 761)
# Found bbox (273, 741, 281, 751)
# Image 04c3aee37.jpg
# Found bbox (564, 68, 573, 97)
# Found bbox (241, 333, 261, 381)
# Found bbox (717, 512, 724, 534)
# Image 04cb74d0a.jpg
# Found bbox (225, 728, 232, 739)
# Image 04cc0a4cc.jpg
# Found bbox (118, 21, 218, 175)
# Image 04ce44ea6.jpg
# Found bbox (398, 325, 413, 346)
# Image 04cefef36.jpg
# Found bbox (731, 344, 742, 356)
# Found bbox (436, 532, 451, 551)
# Image 04d28ccdf.jpg
# Found bbox (625, 298, 634, 313)
# Image 04d3d8d17.jpg
# Found bbox (0, 337, 302, 493)
# Found bbox (669, 417, 674, 425)
# Found bbox (614, 544, 621, 550)
# Image 04deaccf5.jpg
# Found bbox (406, 111, 436, 132)
# Found bbox (353, 129, 367, 154)
# Found bbox (214, 170, 286, 336)
# Found bbox (467, 431, 536, 595)
# Image 04ea43044.jpg
# Found bbox (312, 94, 459, 233)
# Found bbox (390, 203, 418, 232)
# Image 04eeb1c89.jpg
# Found bbox (168, 381, 219, 530)
# Image 04f7b5b8a.jpg
# Found bbox (518, 2, 538, 32)
# Found bbox (524, 33, 550, 64)
# Found bbox (544, 60, 561, 88)
# Found bbox (444, 74, 532, 159)
# Found bbox (561, 81, 584, 99)
# Found bbox (714, 166, 745, 189)
# Image 05015db40.jpg
# Found bbox (133, 623, 220, 678)
# Image 0502d4700.jpg
# Found bbox (489, 295, 681, 387)
# Image 0502d7862.jpg
# Found bbox (465, 375, 491, 448)
# Image 050cb9250.jpg
# Found bbox (130, 582, 164, 668)
# Image 050ebc440.jpg
# Found bbox (66, 503, 97, 577)
# Image 050ef80a1.jpg
# Found bbox (718, 292, 744, 330)
# Image 050f61978.jpg
# Found bbox (597, 284, 611, 311)
# Found bbox (233, 493, 243, 527)
# Image 0510beb50.jpg
# Found bbox (163, 198, 178, 214)
# Image 05131f45f.jpg
# Found bbox (535, 454, 566, 481)
# Found bbox (548, 476, 579, 501)
# Found bbox (596, 486, 630, 524)
# Found bbox (563, 499, 576, 508)
# Found bbox (670, 508, 698, 540)
# Image 05146d6e4.jpg
# Found bbox (416, 694, 428, 709)
# Image 0515125a2.jpg
# Found bbox (397, 92, 421, 175)
# Image 0518ef045.jpg
# Found bbox (122, 577, 204, 672)
# Found bbox (455, 681, 502, 768)
# Image 05208a7d5.jpg
# Found bbox (445, 189, 687, 247)
# Found bbox (369, 331, 452, 359)
# Image 052180438.jpg
# Found bbox (240, 255, 254, 267)
# Image 0523a43d1.jpg
# Found bbox (505, 138, 512, 146)
# Found bbox (605, 256, 612, 264)
# Found bbox (237, 421, 245, 432)
# Found bbox (216, 453, 224, 462)
# Image 052bc532f.jpg
# Found bbox (428, 607, 439, 621)
# Image 052c068ff.jpg
# Found bbox (571, 554, 761, 768)
# Image 052f0492b.jpg
# Found bbox (230, 37, 296, 110)
# Found bbox (736, 91, 768, 166)
# Image 05320baaa.jpg
# Found bbox (171, 262, 195, 282)
# Image 0539a783d.jpg
# Found bbox (761, 510, 768, 526)
# Found bbox (422, 517, 461, 568)
# Found bbox (738, 601, 747, 619)
# Image 053af774f.jpg
# Found bbox (515, 419, 612, 581)
# Image 053d9487a.jpg
# Found bbox (307, 556, 321, 573)
# Image 05426670a.jpg
# Found bbox (382, 590, 402, 603)
# Image 0546baefb.jpg
# Found bbox (177, 24, 206, 42)
# Image 054915d9d.jpg
# Found bbox (719, 74, 750, 127)
# Found bbox (723, 365, 768, 441)
# Image 054ffed4e.jpg
# Found bbox (263, 188, 268, 192)
# Image 0566d4d75.jpg
# Found bbox (515, 231, 530, 238)
# Image 05690c993.jpg
# Found bbox (539, 120, 546, 125)
# Found bbox (648, 162, 655, 167)
# Found bbox (665, 545, 671, 555)
# Image 056f0d58d.jpg
# Found bbox (505, 672, 540, 697)
# Image 056f8adc1.jpg
# Found bbox (118, 118, 229, 281)
# Found bbox (558, 261, 646, 458)
# Image 0570d661f.jpg
# Found bbox (562, 342, 630, 372)
# Found bbox (365, 635, 425, 711)
# Image 0573861e6.jpg
# Found bbox (118, 11, 126, 17)
# Image 05781b203.jpg
# Found bbox (308, 690, 392, 766)
# Image 057c9c643.jpg
# Found bbox (646, 679, 665, 697)
# Image 057db7ee9.jpg
# Found bbox (90, 128, 199, 177)
# Found bbox (680, 293, 697, 306)
# Found bbox (402, 328, 532, 388)
# Image 057ed0d3a.jpg
# Found bbox (236, 170, 278, 254)
# Found bbox (441, 348, 484, 426)
# Found bbox (11, 422, 100, 511)
# Found bbox (697, 571, 716, 630)
# Found bbox (408, 625, 444, 710)
# Image 05828714b.jpg
# Found bbox (693, 598, 726, 680)
# Image 058edc2a5.jpg
# Found bbox (371, 0, 430, 136)
# Image 0593e70e8.jpg
# Found bbox (712, 322, 747, 388)
# Image 059637839.jpg
# Found bbox (385, 284, 436, 339)
# Image 05991fbd9.jpg
# Found bbox (329, 135, 418, 182)
# Image 05a4970a8.jpg
# Found bbox (185, 565, 198, 579)
# Found bbox (71, 574, 93, 584)
# Found bbox (108, 596, 123, 614)
# Found bbox (122, 619, 138, 633)
# Found bbox (82, 624, 98, 639)
# Found bbox (104, 636, 118, 651)
# Image 05b0df131.jpg
# Found bbox (564, 227, 633, 253)
# Found bbox (648, 233, 683, 260)
# Found bbox (337, 563, 392, 642)
# Found bbox (373, 650, 383, 681)
# Image 05b3b9b70.jpg
# Found bbox (487, 153, 495, 160)
# Image 05b59bd2c.jpg
# Found bbox (278, 423, 336, 502)
# Image 05b5eb527.jpg
# Found bbox (129, 303, 191, 424)
# Image 05b700d9b.jpg
# Found bbox (575, 268, 651, 345)
# Found bbox (294, 406, 344, 450)
# Found bbox (164, 520, 177, 539)
# Image 05bded181.jpg
# Found bbox (367, 96, 384, 136)
# Found bbox (532, 105, 548, 116)
# Found bbox (199, 306, 275, 342)
# Image 05d09c217.jpg
# Found bbox (361, 177, 427, 279)
# Image 05d407505.jpg
# Found bbox (504, 78, 570, 115)
# Found bbox (424, 80, 594, 164)
# Image 05d676d50.jpg
# Found bbox (710, 65, 733, 157)
# Image 05e37904a.jpg
# Found bbox (656, 376, 664, 399)
# Image 06049852b.jpg
# Found bbox (493, 519, 608, 584)
# Image 06053bcd2.jpg
# Found bbox (663, 42, 670, 55)
# Found bbox (475, 89, 482, 94)
# Found bbox (481, 114, 487, 126)
# Found bbox (380, 317, 387, 325)
# Found bbox (234, 480, 244, 487)
# Image 06060321c.jpg
# Found bbox (638, 307, 669, 350)
# Image 060905d3b.jpg
# Found bbox (602, 200, 612, 210)
# Image 060cd07f7.jpg
# Found bbox (356, 138, 375, 165)
# Found bbox (223, 277, 255, 339)
# Image 060f09cbf.jpg
# Found bbox (471, 676, 524, 768)
# Image 061088afd.jpg
# Found bbox (608, 589, 642, 614)
# Image 06142ac67.jpg
# Found bbox (248, 279, 268, 309)
# Image 06145c246.jpg
# Found bbox (407, 278, 439, 374)
# Image 061563c99.jpg
# Found bbox (166, 740, 179, 757)
# Image 06159c8b6.jpg
# Found bbox (427, 11, 441, 35)
# Image 0620d9c25.jpg
# Found bbox (728, 388, 737, 396)
# Image 0622e94fd.jpg
# Found bbox (205, 569, 312, 743)
# Image 0624ddeef.jpg
# Found bbox (205, 182, 227, 217)
# Found bbox (764, 192, 768, 197)
# Image 063231b8e.jpg
# Found bbox (536, 662, 602, 749)
# Image 06383c601.jpg
# Found bbox (72, 130, 145, 193)
# Image 063894fc2.jpg
# Found bbox (388, 55, 442, 113)
# Image 063b4cf9c.jpg
# Found bbox (399, 209, 424, 240)
# Image 063f1ce44.jpg
# Found bbox (175, 53, 225, 121)
# Found bbox (662, 124, 725, 200)
# Found bbox (0, 282, 82, 455)
# Found bbox (481, 315, 513, 359)
# Found bbox (630, 435, 675, 500)
# Image 06428c734.jpg
# Found bbox (174, 22, 184, 31)
# Image 064d362ba.jpg
# Found bbox (493, 184, 518, 212)
# Image 064db2f8f.jpg
# Found bbox (662, 46, 720, 121)
# Found bbox (388, 136, 407, 166)
# Found bbox (546, 275, 583, 314)
# Found bbox (366, 410, 420, 502)
# Found bbox (636, 459, 694, 533)
# Image 065175a91.jpg
# Found bbox (526, 103, 536, 115)
# Found bbox (612, 511, 620, 524)
# Image 0656b25a3.jpg
# Found bbox (761, 29, 768, 37)
# Image 0657903ff.jpg
# Found bbox (745, 483, 764, 506)
# Image 0658623f9.jpg
# Found bbox (528, 442, 546, 475)
# Found bbox (543, 452, 552, 471)
# Found bbox (663, 501, 700, 575)
# Found bbox (557, 523, 578, 563)
# Found bbox (604, 595, 625, 629)
# Found bbox (653, 596, 696, 654)
# Found bbox (590, 629, 612, 656)
# Image 0659dc90d.jpg
# Found bbox (83, 83, 108, 98)
# Image 065b83ad4.jpg
# Found bbox (49, 629, 109, 737)
# Image 065c37052.jpg
# Found bbox (669, 450, 686, 464)
# Found bbox (690, 674, 700, 685)
# Image 065ef041d.jpg
# Found bbox (750, 256, 756, 275)
# Found bbox (660, 259, 667, 271)
# Found bbox (679, 259, 685, 274)
# Found bbox (743, 260, 748, 276)
# Image 06627e2ed.jpg
# Found bbox (106, 305, 129, 341)
# Image 0669200c5.jpg
# Found bbox (712, 122, 722, 133)
# Image 0671f1507.jpg
# Found bbox (558, 345, 614, 421)
# Image 0675a8561.jpg
# Found bbox (292, 384, 371, 503)
# Image 069049ec6.jpg
# Found bbox (503, 676, 558, 751)
# Image 069137f77.jpg
# Found bbox (395, 219, 492, 362)
# Image 06919997a.jpg
# Found bbox (686, 123, 718, 178)
# Found bbox (672, 130, 737, 256)
# Found bbox (542, 434, 572, 490)
# Found bbox (684, 666, 720, 756)
# Image 069209ea6.jpg
# Found bbox (440, 644, 461, 665)
# Image 0692c75b0.jpg
# Found bbox (254, 536, 268, 630)
# Image 069413cf8.jpg
# Found bbox (672, 60, 683, 71)
# Found bbox (25, 71, 31, 80)
# Found bbox (488, 104, 493, 112)
# Found bbox (544, 123, 555, 129)
# Found bbox (461, 229, 474, 238)
# Image 0697e0958.jpg
# Found bbox (48, 521, 93, 611)
# Image 069fc657b.jpg
# Found bbox (442, 649, 465, 670)
# Image 06a1b0ec4.jpg
# Found bbox (134, 606, 159, 714)
# Image 06b152f8c.jpg
# Found bbox (519, 560, 565, 644)
# Image 06b5f1274.jpg
# Found bbox (87, 453, 117, 514)
# Image 06b6b6570.jpg
# Found bbox (232, 59, 316, 244)
# Found bbox (47, 560, 144, 762)
# Image 06b8c3648.jpg
# Found bbox (616, 0, 636, 12)
# Image 06bb4c8f2.jpg
# Found bbox (728, 132, 737, 140)
# Image 06c880a4c.jpg
# Found bbox (40, 216, 136, 303)
# Image 06d90df7d.jpg
# Found bbox (473, 99, 497, 194)
# Found bbox (147, 267, 188, 367)
# Image 06db2136f.jpg
# Found bbox (580, 372, 740, 419)
# Image 06db6422a.jpg
# Found bbox (656, 218, 676, 239)
# Image 06dd3e135.jpg
# Found bbox (114, 7, 187, 72)
# Found bbox (475, 543, 768, 768)
# Image 06e3a2388.jpg
# Found bbox (425, 131, 491, 249)
# Image 06e598746.jpg
# Found bbox (294, 77, 320, 146)
# Found bbox (545, 131, 674, 191)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-abe46392aa82> in <module>()
#      10     lbl_0 = label(mask_0)
#      11     props = regionprops(lbl_0)
# ---> 12     img_1 = img_0.copy()
#      13     print ('Image', image)
#      14     j = 0
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %% [markdown]
# Here we calculate the bounding boxes for all `29070` images and save then into a dictionary.

# %%
import gc 
bboxes_dict = {}
i = 0
count_ships = 0
for image in tqdm(images_with_ship):
    img_0 = cv2.imread(test_image_dir+'/' + image)
    rle_0 = masks.query('ImageId=="'+image+'"')['EncodedPixels']
    mask_0 = masks_as_image(rle_0)
    

    #
    # 
    lbl_0 = label(mask_0) 
    props = regionprops(lbl_0)
    bboxes = []
    count_ships = count_ships + len(props)
    for prop in props:
        bboxes.append(prop.bbox)
        
        
    i = i + 1
    if i % 500 == 0:
        gc.collect()    

    bboxes_dict[image] = bboxes.copy()

# %% [markdown]
# Let us plot some bounding boxes right from the dictionary we just created.

# %%
dict_images = list(bboxes_dict.keys())
for i in range(5):
    image = dict_images[10+i]
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15, 5))
    img_0 = cv2.imread(train_image_dir+'/' + image)
    rle_0 = masks.query('ImageId=="'+image+'"')['EncodedPixels']
    mask_0 = masks_as_image(rle_0)
    img_1 = img_0.copy()
    bboxs = bboxes_dict[image]
    for bbox in bboxs:
        cv2.rectangle(img_1, (bbox[1], bbox[0]), (bbox[3], bbox[2]), (255, 0, 0), 2)


    ax1.imshow(img_0)
    ax2.imshow(mask_0[...,0], cmap='gray')
    ax3.imshow(img_1)
    plt.show()

# %% [markdown]
# The final touch.. I export these bounding boxes for everyone to use in a Pandas dataframe form.

# %%
bboxes_df = pd.DataFrame([bboxes_dict])
bboxes_df = bboxes_df.transpose()
bboxes_df.columns = ['bbox_list']
bboxes_df.head()

# %%
bboxes_df.to_csv('bbox_dictionary.csv')
